# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os
import investpy as df
import investpy
import json
import csv
import operator
from matplotlib import dates
import datetime
from sqlalchemy.orm import Session
import plotly.graph_objects as go
from datetime import datetime

# %%
df_Energy = investpy.get_index_historical_data(index='S&P 500 ENERGY', country="united states",from_date='01/01/2010',to_date='31/12/2019')
#df_Energy

df_Crypto = investpy.get_crypto_historical_data(crypto='bitcoin', from_date='01/01/2010',to_date='31/12/2019')
#df_Crypto

df_AAPL = investpy.get_stock_historical_data(stock='AAPL', country="united states", from_date='01/01/2010',to_date='31/12/2019')
df_AAPL
# Out:
#              Open   High    Low  Close     Volume Currency
# Date
# 2010-01-04   7.62   7.66   7.58   7.64  493728704      USD
# 2010-01-05   7.66   7.70   7.62   7.66  601904640      USD
# 2010-01-06   7.66   7.69   7.53   7.53  552158912      USD
# 2010-01-07   7.56   7.57   7.47   7.52  477129760      USD
# 2010-01-08   7.51   7.57   7.47   7.57  447876768      USD
# ...           ...    ...    ...    ...        ...      ...
# 2019-12-24  71.17  71.22  70.73  71.07   48478856      USD
# 2019-12-26  71.20  72.50  71.17  72.48   93336016      USD
# 2019-12-27  72.78  73.49  72.03  72.45  146371744      USD
# 2019-12-30  72.36  73.17  71.31  72.88  144238464      USD
# 2019-12-31  72.48  73.42  72.38  73.41  100990496      USD
#
# [2517 rows x 6 columns]

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure(data=[go.Candlestick(x=df_AAPL['Date'],
                open=df_AAPL['Open'], high=df_APPL['High'],
                low=df_APPL['Low'], close=df_APPL['Price'])
                     ])

fig.layout.update(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-95dba93f96a6> in <module>
#       2 import pandas as pd
#       3
# ----> 4 fig = go.Figure(data=[go.Candlestick(x=df_Appl['Date'],
#       5                 open=df_Appl['Open'], high=df_Appl['High'],
#       6                 low=df_Appl['Low'], close=df_Appl['Price'])
#
# NameError: name 'df_Appl' is not defined

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Price'])])

fig.show()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-66435bebd3fc> in <module>
# ----> 1 df = investpy.get_index_historical_data(index='CVX', country="united states",from_date='01/01/2010',to_date='31/12/2019')
#       2 df
#
# NameError: name 'investpy' is not defined
